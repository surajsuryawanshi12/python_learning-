# %% [markdown]
# <a href="https://colab.research.google.com/github/surajsuryawanshi12/python_learning-/blob/main/day_2_data_types_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Data types in python
# primitive data type :- int, float, boolean
# non- primitive data types :- string ,list, tuple, dictionarys, set | collection of elements
# value is data ----> data types

# %%
1728 ** (1/3)
# Out:
# 11.999999999999998

# %%
0.2+0.1
# Out:
# 0.30000000000000004

# %%
bin(7)
# Out:
# '0b111'

# %%
 _x  = 'simma'
print(_x)
# Out:
# simma

# %% [markdown]
# # Representation of data types

# %%
# Recognise an integer : Number without decimal 4, 56, 32
# float : Number  with decimal  4.35
# Boolean : True, False | T cap, rue --Small
# true --> Not a boolean

# %%
x= 4.5
type(x) # gives float data type of any values
# Out:
# float

# %%
_var = 'aniket' #---> String data type
type(_var)
# Out:
# str

# %%
_list = [3,5,6,8]  #---> list data type
type(_list)
# Out:
# list

# %%
_var = (3,4,5,6) #---> tuple data type
type(_var)
# Out:
# tuple

# %%
_String = 'I\'m aniket suryawanshi' # string in single quote
print(_String)
# Out:
# I'm aniket suryawanshi

# %%
_String = "I'm aniket suryawanshi" # string in double quote
print(_String)
# Out:
# I'm aniket suryawanshi

# %%
_string_var  = """ hello i am aniket
              where do you live
              what are you doing
              can you check the food int the freser
              are you free for some time
               """
               # this is triple quote string ( multiliner)

print(_string_var)
# Out:
#  hello i am aniket
#               where do you live
#               what are you doing
#               can you check the food int the freser
#               are you free for some time

# %%
_string_var = ''' heelo anike how are
you are you fine
 heelo anike how are
you are you fine
where are you from
how was your day '''
print(_string_var)
# Out:
#  heelo anike how are
# you are you fine
#  heelo anike how are
# you are you fine
# where are you from
# how was your day

# %%
# Dictionary : Key & Value Pair
# Dicrionary : elements ? How many key & values pairs are threr?
_dict_var = {'Student1':40,'student2':50, 'a':70, 'b':80}
print(_dict_var)
# Out:
# {'Student1': 40, 'student2': 50, 'a': 70, 'b': 80}

# %%
_list = ['a','b','c',8,9,10]
type(_list)
# Out:
# list

# %%
#set:- set values with curly baracket
# set : only values
# Dictionary : key:value
# set removes the dupicates values

# %%
_set ={4, 4,5,6,7,7}
print(_set)
# Out:
# {4, 5, 6, 7}

# %%
_var = 'true '
len(_var)
# Out:
# 5

# %%
_var_list = [3,4.0, True, 'a. ','ab',False]
len(_var_list)
# Out:
# 6

# %%
_var = [3  , 4,True, 'a.,,,'] # in the list len only consider the element as the number not included spaces comma seperated each element
len(_var)
# Out:
# 4

# %%
# String
# (\) this is not pick as a element it except
# in len() it take space also as an element

_var = "h\'a"
len(_var)
# Out:
# 3

# %% [markdown]
# # Emplty data Type, Single Elements

# %%
#string  :- insite quotes everythimh is an elements

# %%
# empty data types : String
_var = ' {}'# "",''' '''
len(_var)
# Out:
# 3

# %%
_empty = [ ]
len(_empty)
# Out:
# 0

# %%
# list acts diffrent from string
# String : Everything inside the quotes will be a character including space
# List : Elements are seperated by coma and space is not counted

# inddifr the string '4,5,6,7,8' everything becomes a string
# inside the list [4,5,6,7,8,3] ---> everything retains its own data type

# %%
_var = (3,) # now this is tuple
type(_var)
_var = (3) # now this is int
print(type(_var))
# Out:
# <class 'int'>

# %%
(3) * 4
# Out:
# 12

# %%
(3) * 4
# Out:
# 12

# %%
_dict = {'a':20,'b':50}
len(_dict)
# Out:
# 2

# %%
# how to create empty set and empty dictionary
# for set,  set() this function for empty data type
# for dict {} cury bracket for empty data type

#  here example
_set = set()
type(_set)
# Out:
# set

# %%
_dict = {}
type(_dict)
# Out:
# dict

# %%
#list
# No restrictions of elements for list Dupyard of data
# Everything is accepated inside the list, duplicates are allowerd
_var_list = [1,(3,4),"dre.",[3,4],{4,5,3},{3:4}] # list contain all data types inside it
print(_var_list)
# Out:
# [1, (3, 4), 'dre.', [3, 4], {3, 4, 5}, {3: 4}]

# %%
#tuple
# tupel is also similar to list data type
_var_tuple = (1,4,5,'dresf,.',[424,34,4],{4,54,5},{'a':4})
print(_var_tuple)
# Out:
# (1, 4, 5, 'dresf,.', [424, 34, 4], {4, 5, 54}, {'a': 4})

# %%
# Restraction with Dictionary
# key : Int, float, Boolean, String & Tuple are accepted | list, dict & set are not accepted as key
# value : All are accepted
_var_Dict = { 1,2,3,3,56,7}
print(_var_Dict)
# Out:
# {1, 2, 3, 7, 56}

# %%
# duplicates value in key
# in dictionary : Your keys must be unique | key cant have duplicates values
# exceptions : true is considerd as 1, false is considerd as 0

# %%
# Note for dictionary
# 1. key : list , disct & set as not accepted
# 2. value: accept all
# 3. varlable(key) : you extract the value | key willl act as an address / index
# 4. key must be unique otherwise last right must key and value pair is related
# 5. all data will retain their data types, it will not lose assens like string

# %%
# set
# set act similar to dictionary : list dict, set will not be accpeted
_var_Set = {2,3,4,{343,3,4,4}}
print(_var_Set) # error beacuse we include set inside it

# set will not accept duplicates
# set only values are accepted
# string, list, and tuple :- no restriction
# -dict : keys will not accept list, dict, and set
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-23-2458745049.py in <cell line: 0>()
#       1 # set
#       2 # set act similar to dictionary : list dict, set will not be accpeted
# ----> 3 _var_Set = {2,3,4,{343,3,4,4}}
#       4 print(_var_Set)
#
# TypeError: unhashable type: 'set'

# %%
_var = {1,True} # set not consider true or and data tyepe name as element
len(_var)
# Out:
# 1

# %% [markdown]
# # orderd & unorderd

# %%
# orderd : position + object
# unorderd : object

# %%
# String, List, Tuple : Ordered
# Dict, set : Unordered

# %%
# String -> ordered
# Position + Elements will matter
'hello' == 'elloh' # false
# Out:
# False

# %%
# tuples : ordered
(2,1,3) == (1,2,3) ##
# Out:
# False
